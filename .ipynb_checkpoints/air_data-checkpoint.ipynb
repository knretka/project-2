# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
cities = pd.read_csv('uscities.csv')
cities.head
# Out:
# <bound method NDFrame.head of                city    city_ascii state_id    state_name  county_fips  \
# 0       South Creek   South Creek       WA    Washington        53053
# 1            Roslyn        Roslyn       WA    Washington        53037
# 2           Sprague       Sprague       WA    Washington        53043
# 3        Gig Harbor    Gig Harbor       WA    Washington        53053
# 4      Lake Cassidy  Lake Cassidy       WA    Washington        53061
# ...             ...           ...      ...           ...          ...
# 28884      Montrose      Montrose       SD  South Dakota        46087
# 28885     Spearfish     Spearfish       SD  South Dakota        46081
# 28886         Emery         Emery       SD  South Dakota        46061
# 28887     Watertown     Watertown       SD  South Dakota        46029
# 28888       Buffalo       Buffalo       SD  South Dakota        46063
#
#       county_name county_fips_all county_name_all      lat       lng  \
# ...

# %%
cities = cities.loc[~cities["population"].isnull()]

# %%
cities = cities.sort_values("population", ascending=False)

# %%
cities = cities.head(500)
cities
# Out:
#               city   city_ascii state_id  state_name  county_fips  \
# 9730      New York     New York       NY    New York        36061
# 14121  Los Angeles  Los Angeles       CA  California         6037
# 16289      Chicago      Chicago       IL    Illinois        17031
# 2882         Miami        Miami       FL     Florida        12086
# 4464        Dallas       Dallas       TX       Texas        48113
# ...            ...          ...      ...         ...          ...
# 12717    Lafayette    Lafayette       CO    Colorado         8013
# 20925       Edmond       Edmond       OK    Oklahoma        40109
# 18129      Fishers      Fishers       IN     Indiana        18057
# 14320  Westminster  Westminster       CA  California         6059
# 20582   Germantown   Germantown       MD    Maryland        24031
#
#        county_name                county_fips_all  \
# 9730      New York                          36061
# 14121  Los Angeles                          06037
# ...

# %%
cities.to_csv('topcities.csv')
